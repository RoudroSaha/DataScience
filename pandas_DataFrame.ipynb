# %% [markdown]
# # Pandas DataFrame #

# %%
"""
-pandas is a python library for working with tabular data.
-pandas is used for analyze ,clean , explore and manipulate data.
-pandad allows us to analze big data and make conclusions based on statistical theories.


objectives:
-we will learn how to us pandas dataframe methods
- we will learn how to use custom dataframe methods
-we will count the categorical varialbles
-we will group dataframes by columns
-we will learn to use pivat tables for data amalysis
"""

import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 15
#       1 """
#       2 -pandas is a python library for working with tabular data.
#       3 -pandas is used for analyze ,clean , explore and manipulate data.
#    (...)     12 -we will learn to use pivat tables for data amalysis
#      13 """
# ---> 15 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
"""
-pandas is a python library for working with tabular data.
-pandas is used for analyze ,clean , explore and manipulate data.
-pandad allows us to analze big data and make conclusions based on statistical theories.


objectives:
-we will learn how to us pandas dataframe methods
- we will learn how to use custom dataframe methods
-we will count the categorical varialbles
-we will group dataframes by columns
-we will learn to use pivat tables for data amalysis
"""

import pandas as pd

# %%
import sys
print(sys.executable)
# Out:
# /home/roudro_saha/RouDro/DataScience/.env/bin/python
